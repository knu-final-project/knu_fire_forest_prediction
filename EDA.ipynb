# %% [markdown]
# ### Pandas Profiling (EDA)

# %%
# !pip install pandas_profiling
# Out:
# Requirement already satisfied: pandas_profiling in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (3.1.0)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (0.1.12)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (1.22.3)
# Requirement already satisfied: tangled-up-in-unicode==0.1.0 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (0.1.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (1.4.1)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (6.0)
# Requirement already satisfied: multimethod>=1.4 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (1.7)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (1.9.0)
# Requirement already satisfied: markupsafe~=2.0.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (2.0.1)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (0.5.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (3.0.3)
# Requirement already satisfied: requests>=2.24.0 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (1.8.0)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (3.5.1)
# Requirement already satisfied: phik>=0.11.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (0.12.2)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (0.11.2)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (0.7.4)
# Requirement already satisfied: joblib~=1.0.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (1.0.1)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas_profiling) (4.63.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (2.7.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (21.4.0)
# Requirement already satisfied: imagehash in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (4.2.1)
# Requirement already satisfied: Pillow in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.31.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from pydantic>=1.8.1->pandas_profiling) (4.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas_profiling) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from requests>=2.24.0->pandas_profiling) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from requests>=2.24.0->pandas_profiling) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from requests>=2.24.0->pandas_profiling) (1.26.9)
# Requirement already satisfied: colorama in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from tqdm>=4.48.2->pandas_profiling) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\dkq50\anaconda3\envs\conda38\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas_profiling) (1.3.0)

# %%
# 라이브러리
import pandas as pd
from pandas_profiling import ProfileReport 
import matplotlib
from matplotlib import font_manager, rc
import platform

# %%
# 데이터 불러오기
data = pd.read_csv('산불발생통계.txt')
data.head(1)
# Out:
#    Unnamed: 0  damagearea  endday  endmonth   endtime  endyear firecause  \
# 0           0        0.01      29        11  12:44:00     2018        기타
#
#   locbunji locdong locgungu locmenu locsi  startday startdayofweek  \
# 0      산34      대문       진천      백곡    충북        29            목요일
#
#    startmonth starttime  startyear
# 0          11  12:14:00       2018

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'damagearea', 'endday', 'endmonth', 'endtime', 'endyear',
#        'firecause', 'locbunji', 'locdong', 'locgungu', 'locmenu', 'locsi',
#        'startday', 'startdayofweek', 'startmonth', 'starttime', 'startyear'],
#       dtype='object')

# %%
data2 = data.drop('Unnamed: 0', axis=1)
data2.head()
# Out:
#    damagearea  endday  endmonth   endtime  endyear firecause locbunji locdong  \
# 0        0.01      29        11  12:44:00     2018        기타      산34      대문
# 1        0.08      26         8  18:00:00     2019     입산자실화     산102      검산
# 2        0.01      26         8  16:50:00     2019        기타     산120      석정
# 3        0.02      19         9  16:20:00     2019     쓰레기소각      6-4      녹도
# 4        0.16      30         9  18:00:00     2019     입산자실화     산267      도평
#
#   locgungu locmenu locsi  startday startdayofweek  startmonth starttime  \
# 0       진천      백곡    충북        29            목요일          11  12:14:00
# 1       홍천      서석    강원        26            월요일           8  12:10:00
# 2       평택      포승    경기        26            월요일           8  16:22:00
# 3       보령      오천    충남        19            목요일           9  10:38:00
# 4       포천      이동    경기        29            일요일           9  17:42:00
#
#    startyear
# 0       2018
# 1       2019
# 2       2019
# 3       2019
# 4       2019

# %%
############ 한글 폰트 지정하는 부분 #################
if platform.system() == 'Windows':
# 윈도우인 경우
    font_path = "C:/Windows/Fonts/NGULIM.TTF"
    font = font_manager.FontProperties(fname=font_path).get_name()
    rc('font', family=font)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

#그래프에서 마이너스 기호가 표시되도록 하는 설정입니다.  
matplotlib.rcParams['axes.unicode_minus'] = False   


# 레포트 생성 --> html 파일로 저장하기  
## 한글이 깨지시는 분은 제일 아래 코드로 실행해주세요
report = data2.profile_report()
report.to_file('산불발생통계_EDA.html')
# Out:
# Summarize dataset: 100%|██████████| 78/78 [00:05<00:00, 14.51it/s, Completed]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]C:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# C:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50836 (\N{HANGUL SYLLABLE YO}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# C:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# C:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# C:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# C:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# C:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# C:\Users\dkq50\anaconda3\envs\conda38\lib\site-packages\pandas_profiling\visualisation\utils.py:66: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   plt.savefig(image_str, format=image_format)
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.51s/it]
# Render HTML: 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 99.37it/s]
