# %% [markdown]
# ### Pandas Profiling (EDA)

# %%
# !pip install pandas_profiling
# Out:
# ...
#   Using cached pandas_profiling-3.1.0-py2.py3-none-any.whl (261 kB)
# ...
#   Using cached multimethod-1.7-py3-none-any.whl (9.5 kB)
# ...
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# ...
#   Using cached pydantic-1.9.0-cp37-cp37m-win_amd64.whl (2.0 MB)
# ...
#   Using cached matplotlib-3.5.1-cp37-cp37m-win_amd64.whl (7.2 MB)
# ...
#      -------------------------------------- 673.5/673.5 KB 1.8 MB/s eta 0:00:00
# ...
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# ...
#   Using cached MarkupSafe-2.0.1-cp37-cp37m-win_amd64.whl (14 kB)
# ...
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# ...
#   Using cached joblib-1.0.1-py3-none-any.whl (303 kB)
# ...
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# ...
#      -------------------------------------- 899.5/899.5 KB 2.4 MB/s eta 0:00:00
# ...
#   Using cached charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
# ...

# %%
# 라이브러리
import pandas as pd
from pandas_profiling import ProfileReport 
import matplotlib
from matplotlib import font_manager, rc
import platform

# %%
# 데이터 불러오기
data = pd.read_csv('산불발생통계.txt')
data.head(1)
# Out:
#    Unnamed: 0  damagearea  endday  endmonth   endtime  endyear firecause  \
# 0           0        0.01      29        11  12:44:00     2018        기타
#
#   locbunji locdong locgungu locmenu locsi  startday startdayofweek  \
# 0      산34      대문       진천      백곡    충북        29            목요일
#
#    startmonth starttime  startyear
# 0          11  12:14:00       2018

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'damagearea', 'endday', 'endmonth', 'endtime', 'endyear',
#        'firecause', 'locbunji', 'locdong', 'locgungu', 'locmenu', 'locsi',
#        'startday', 'startdayofweek', 'startmonth', 'starttime', 'startyear'],
#       dtype='object')

# %%
data2 = data.drop('Unnamed: 0', axis=1)
data2.head()
# Out:
#    damagearea  endday  endmonth   endtime  endyear firecause locbunji locdong  \
# 0        0.01      29        11  12:44:00     2018        기타      산34      대문
# 1        0.08      26         8  18:00:00     2019     입산자실화     산102      검산
# 2        0.01      26         8  16:50:00     2019        기타     산120      석정
# 3        0.02      19         9  16:20:00     2019     쓰레기소각      6-4      녹도
# 4        0.16      30         9  18:00:00     2019     입산자실화     산267      도평
#
#   locgungu locmenu locsi  startday startdayofweek  startmonth starttime  \
# 0       진천      백곡    충북        29            목요일          11  12:14:00
# 1       홍천      서석    강원        26            월요일           8  12:10:00
# 2       평택      포승    경기        26            월요일           8  16:22:00
# 3       보령      오천    충남        19            목요일           9  10:38:00
# 4       포천      이동    경기        29            일요일           9  17:42:00
#
#    startyear
# 0       2018
# 1       2019
# 2       2019
# ...

# %%
############ 한글 폰트 지정하는 부분 #################
if platform.system() == 'Windows':
# 윈도우인 경우
    font_path = "C:/Windows/Fonts/NGULIM.TTF"
    font = font_manager.FontProperties(fname=font_path).get_name()
    rc('font', family=font)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')

#그래프에서 마이너스 기호가 표시되도록 하는 설정입니다.  
matplotlib.rcParams['axes.unicode_minus'] = False   


# 레포트 생성 --> html 파일로 저장하기  
## 한글이 깨지시는 분은 제일 아래 코드로 실행해주세요
report = data2.profile_report()
report.to_file('산불발생통계_EDA.html')
# Out:
# ...
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:90: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:90: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:90: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:90: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\textpath.py:90: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# ...

# %%
data2
# Out:
#       damagearea  endday  endmonth   endtime  endyear firecause locbunji  \
# 0           0.01      29        11  12:44:00     2018        기타      산34
# 1           0.08      26         8  18:00:00     2019     입산자실화     산102
# 2           0.01      26         8  16:50:00     2019        기타     산120
# 3           0.02      19         9  16:20:00     2019     쓰레기소각      6-4
# 4           0.16      30         9  18:00:00     2019     입산자실화     산267
# ...          ...     ...       ...       ...      ...       ...      ...
# 4729        1.30      19         3  13:20:00     2017   농산폐기물소각      산70
# 4730        0.03      19         3  13:30:00     2017  기타(직접입력)       산6
# 4731        0.10      19         3  14:58:00     2017   농산폐기물소각      산82
# 4732        0.03      19         3  14:25:00     2017   농산폐기물소각       산2
# 4733        0.20      19         3  15:00:00     2017     쓰레기소각     산191
#
#      locdong locgungu locmenu locsi  startday startdayofweek  startmonth  \
# ...

# %%
import numpy as np 
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4734 entries, 0 to 4733
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   damagearea      4734 non-null   float64
#  1   endday          4734 non-null   int64
#  2   endmonth        4734 non-null   int64
#  3   endtime         4734 non-null   object
#  4   endyear         4734 non-null   int64
#  5   firecause       4734 non-null   object
#  6   locbunji        4734 non-null   object
#  7   locdong         4734 non-null   object
#  8   locgungu        4734 non-null   object
#  9   locmenu         4734 non-null   object
#  10  locsi           4734 non-null   object
#  11  startday        4734 non-null   int64
#  12  startdayofweek  4734 non-null   object
#  13  startmonth      4734 non-null   int64
#  14  starttime       4734 non-null   object
#  15  startyear       4734 non-null   int64
# dtypes: float64(1), int64(6), object(9)
# ...

# %%
data2.isnull().sum()
# Out:
# damagearea        0
# endday            0
# endmonth          0
# endtime           0
# endyear           0
# firecause         0
# locbunji          0
# locdong           0
# locgungu          0
# locmenu           0
# locsi             0
# startday          0
# startdayofweek    0
# startmonth        0
# starttime         0
# startyear         0
# dtype: int64

# %%
data2.to_csv("df_fire.csv", header=True, index=False, encoding='euc-kr')
